# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
dataset = pd.read_csv('../Data/Salary_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state= 0)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predit = regression.predict(x_test)

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_train, regression.predict(x_train), color='blue')
plt.title("Simple linear regression")
plt.xlabel('years of experience')
plt.ylabel('salary')
plt.show()

# %%
plt.scatter(x_test, y_test, color='red')
plt.plot(x_train, regression.predict(x_train), color='blue')
plt.title("Simple linear regression(test)")
plt.xlabel('years of experience')
plt.ylabel('salary')
plt.show()

# %%
predit12year = regression.predict([[12]])
print(predit12year)
# Out:
# [138531.00067138]

# %%
print(regression.coef_) #coefficiants
print(regression.intercept_)
#formule
#prediction = regression.coef_ * year of experience + regression.intercept_
# Out:
# [9312.57512673]
# 26780.099150628157
